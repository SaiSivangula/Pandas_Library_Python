# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiSivangula/Pandas_Library_Python/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

Labels = ['a','b','c']
List = [10,20,30]
arr = np.array(List)
dic = {'a':10,'b':20,'c':30}

print("Labels",Labels)
print("List",List)
print("arr",arr)
print("dic",dic)
# Out:
# Labels ['a', 'b', 'c']
# List [10, 20, 30]
# arr [10 20 30]
# dic {'a': 10, 'b': 20, 'c': 30}

# %%
a=pd.Series(data=List)
print(a)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
a = pd.Series(List,Labels)
print(a)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(dic)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(Labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser1=pd.Series([0,1,2,3],["CA","CO","NV","AZ"])
ser2=pd.Series([1,2,4,7],["CA","NV","VS","AZ"])

print(ser1['AZ'])
print(ser2[3])
print(ser1[1:4])
# Out:
# 3
# 7
# CO    1
# NV    2
# AZ    3
# dtype: int64
# <ipython-input-24-c14db110530b>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(ser2[3])

# %%
ser3=ser1+ser2
print(ser3)
# Out:
# AZ    10.0
# CA     1.0
# CO     NaN
# NV     4.0
# VS     NaN
# dtype: float64

# %%
from numpy.random import randn

# %%
np.random.seed(101)
matrix_data = randn(5,4)
row_labels = ['A','B','C','D','E']
colum_labels = ['X','Y','W','Z']

df = pd.DataFrame(data=matrix_data,index=row_labels,columns=colum_labels)
print(df)
# Out:
#           X         Y         W         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['X']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: X, dtype: float64

# %%
df[['X','W']]
# Out:
#           X         W
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %%
df.W
# Out:
# A    0.907969
# B   -0.848077
# C    0.528813
# D   -0.933237
# E    2.605967
# Name: W, dtype: float64

# %%
df['new'] = df['X'] + df['W']
print(df)
# Out:
#           X         Y         W         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1,inplace=True)
print(df)
# Out:
#           X         Y         W         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['E']
# Out:
# X    0.190794
# Y    1.978757
# W    2.605967
# Z    0.683509
# Name: E, dtype: float64

# %%
df.loc[['A','C']]
# Out:
#           X         Y         W         Z
# A  2.706850  0.628133  0.907969  0.503826
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df.iloc[[2,4]]
# Out:
#           X         Y         W         Z
# C -2.018168  0.740122  0.528813 -0.589001
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc[['B','C'],['Y','W','Z']]
# Out:
#           Y         W         Z
# B -0.319318 -0.848077  0.605965
# C  0.740122  0.528813 -0.589001

# %%
df.iloc[1:3]
# Out:
#           X         Y         W         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df1 = pd.DataFrame({'A':[2,3,np.nan],'B':[np.nan,1,np.nan],'C':[1,9,2]})
df1['states'] ="CA BC DS".split()
df1.set_index('states',inplace=True)
print(df1)
# Out:
#           A    B  C
# states
# CA      2.0  NaN  1
# BC      3.0  1.0  9
# DS      NaN  NaN  2

# %%
df1.dropna(axis=1)
# Out:
#         C
# states
# CA      1
# BC      9
# DS      2

# %% [markdown]
# ###Tresh
# Returns not null values in rows and columns

# %%
df1.dropna(axis=0, thresh=3)
# Out:
#           A    B  C
# states
# BC      3.0  1.0  9

# %%
df1.fillna(value=df1['C'].mean())
# Out:
#           A    B  C
# states
# CA      2.0  4.0  1
# BC      3.0  1.0  9
# DS      4.0  4.0  2

# %%
df1
# Out:
#           A    B  C
# states
# CA      2.0  NaN  1
# BC      3.0  1.0  9
# DS      NaN  NaN  2

# %%
df2 = pd.DataFrame({'Company':['GOOG','CIN','GFG'],'Person':['Sam','Charlie','Amy'],'Sales':[200,120,340]})
# Out:
#           Person  Sales
# Company
# CIN      Charlie    120
# GFG          Amy    340
# GOOG         Sam    200

# %%
a=df2.groupby('Company')
print(a.sum())
# Out:
#           Person  Sales
# Company
# CIN      Charlie    120
# GFG          Amy    340
# GOOG         Sam    200

# %%
print(pd.DataFrame(df2.groupby('Company').describe().loc['CIN']))
# Out:
#                CIN
# Sales count    1.0
#       mean   120.0
#       std      NaN
#       min    120.0
#       25%    120.0
#       50%    120.0
#       75%    120.0
#       max    120.0

# %%
pd1 = pd.DataFrame({'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3'],'C':['C0','C1','C2','C3']})
pd2 =pd.DataFrame({'A':['A4','A5','A6','A7'],'B':['B4','B5','B6','B7'],'C':['C4','C5','C6','C7']})

# %%
pd1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3

# %%
pd2
# Out:
#     A   B   C
# 0  A4  B4  C4
# 1  A5  B5  C5
# 2  A6  B6  C6
# 3  A7  B7  C7

# %%
pd.concat([pd1,pd2],axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A4  B4  C4
# 1  A1  B1  C1  A5  B5  C5
# 2  A2  B2  C2  A6  B6  C6
# 3  A3  B3  C3  A7  B7  C7

# %%
k1 = pd.DataFrame({'A':['A1','A2','A3','A4'],'B':['B1','B2','B3','B4']},index=['K0','K1','K2','K3'])
k2 = pd.DataFrame({'C':['C1','C2','C3','C4'],'D':['D1','D2','D3','D4']},index=['K0','K2','K3','K4'])

# %%
k1
# Out:
#      A   B
# K0  A1  B1
# K1  A2  B2
# K2  A3  B3
# K3  A4  B4

# %%
k2
# Out:
#      C   D
# K0  C1  D1
# K2  C2  D2
# K3  C3  D3
# K4  C4  D4

# %%
k1.join(k2)
# Out:
#      A   B    C    D
# K0  A1  B1   C1   D1
# K1  A2  B2  NaN  NaN
# K2  A3  B3   C2   D2
# K3  A4  B4   C3   D3

# %%
k1.join(k2,how='inner')
# Out:
#      A   B   C   D
# K0  A1  B1  C1  D1
# K2  A3  B3  C2  D2
# K3  A4  B4  C3  D3

# %%
a=k1.join(k2, how='outer')
a
# Out:
#       A    B    C    D
# K0   A1   B1   C1   D1
# K1   A2   B2  NaN  NaN
# K2   A3   B3   C2   D2
# K3   A4   B4   C3   D3
# K4  NaN  NaN   C4   D4

# %%
a.fillna(value=0)
# Out:
#      A   B   C   D
# K0  A1  B1  C1  D1
# K1  A2  B2   0   0
# K2  A3  B3  C2  D2
# K3  A4  B4  C3  D3
# K4   0   0  C4  D4

# %%
b = pd.DataFrame({'col1':[1,3,4,5,6,8],
                  'col2':['ddd',44,'ss','55',66,'yy'],
                  'col3':['sai','da','ram','yer','uyk','lop']})
b
# Out:
#    col1 col2 col3
# 0     1  ddd  sai
# 1     3   44   da
# 2     4   ss  ram
# 3     5   55  yer
# 4     6   66  uyk
# 5     8   yy  lop

# %%
b.loc[:,'col1']
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    8
# Name: col1, dtype: int64

# %%
def fun(a):
  if(a>10):
    return a+10
  else:
    return a-10

fun(20)
# Out:
# 30

# %%
b['new'] = b['col1'].apply(fun)
b
# Out:
#    col1 col2 col3  new
# 0     1  ddd  sai   -9
# 1     3   44   da   -7
# 2     4   ss  ram   -6
# 3     5   55  yer   -5
# 4     6   66  uyk   -4
# 5     8   yy  lop   -2

# %%
b['len'] = b['col3'].apply(len)
b
# Out:
#    col1 col2 col3  new  len
# 0     1  ddd  sai   -9    3
# 1     3   44   da   -7    2
# 2     4   ss  ram   -6    3
# 3     5   55  yer   -5    3
# 4     6   66  uyk   -4    3
# 5     8   yy  lop   -2    3

# %%
b['new'].apply(lambda a:a*2)
# Out:
# 0   -18
# 1   -14
# 2   -12
# 3   -10
# 4    -8
# 5    -4
# Name: new, dtype: int64

# %%
b['new'].describe()
# Out:
# count    6.000000
# mean    -5.500000
# std      2.428992
# min     -9.000000
# 25%     -6.750000
# 50%     -5.500000
# 75%     -4.250000
# max     -2.000000
# Name: new, dtype: float64

# %%
b['new'].count()
# Out:
# 6

# %%
b['new'].std()
# Out:
# 2.4289915602982237
